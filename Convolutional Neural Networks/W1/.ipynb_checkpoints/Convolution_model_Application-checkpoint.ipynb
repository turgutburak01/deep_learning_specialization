# %%
import math
import numpy as np
import h5py
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
from PIL import Image
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
from tensorflow.python.framework import ops
from cnn_utils import *

# %matplotlib inline
np.random.seed(1)

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_happy_dataset()

# Normalize
X_train = X_train_orig/255.
X_test = X_test_orig/255.

# Reshape
Y_train = Y_train_orig.T
Y_test = Y_test_orig.T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 600
# number of test examples = 150
# X_train shape: (600, 64, 64, 3)
# Y_train shape: (600, 1)
# X_test shape: (150, 64, 64, 3)
# Y_test shape: (150, 1)

# %%
index = 123
plt.imshow(X_train_orig[index])
plt.show()

# %%
def happyModel():
    model = tf.keras.Sequential([
            tfl.ZeroPadding2D(padding=(3,3), input_shape=(64,64,3)),
            tfl.Conv2D(32, (7,7)),
            tfl.BatchNormalization(axis=3),
            tfl.ReLU(),
            tfl.MaxPool2D(),
            tfl.Flatten(),
            tfl.Dense(1, activation='sigmoid')
    ])
    
    return model

# %%
happy_model = happyModel()
happy_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  zero_padding2d (ZeroPadding  (None, 70, 70, 3)        0
#  2D)
#
#  conv2d (Conv2D)             (None, 64, 64, 32)        4736
#
#  batch_normalization (BatchN  (None, 64, 64, 32)       128
#  ormalization)
#
#  re_lu (ReLU)                (None, 64, 64, 32)        0
#
#  max_pooling2d (MaxPooling2D  (None, 32, 32, 32)       0
#  )
#
#  flatten (Flatten)           (None, 32768)             0
#
#  dense (Dense)               (None, 1)                 32769
#
# =================================================================
# Total params: 37,633
# Trainable params: 37,569
# Non-trainable params: 64
# _________________________________________________________________

# %%
happy_model.compile(optimizer='adam',
                    loss='binary_crossentropy',
                    metrics=['accuracy'])

# %%
happy_model.fit(X_train, Y_train, epochs=10, batch_size=16)
# Out:
# Epoch 1/10
# 38/38 [==============================] - 3s 58ms/step - loss: 1.0108 - accuracy: 0.7400
# Epoch 2/10
# 38/38 [==============================] - 2s 62ms/step - loss: 0.2422 - accuracy: 0.9067
# Epoch 3/10
# 38/38 [==============================] - 2s 63ms/step - loss: 0.3024 - accuracy: 0.8867
# Epoch 4/10
# 38/38 [==============================] - 3s 81ms/step - loss: 0.1121 - accuracy: 0.9583
# Epoch 5/10
# 38/38 [==============================] - 3s 80ms/step - loss: 0.0971 - accuracy: 0.9667
# Epoch 6/10
# 38/38 [==============================] - 3s 77ms/step - loss: 0.1592 - accuracy: 0.9317
# Epoch 7/10
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0934 - accuracy: 0.9733
# Epoch 8/10
# 38/38 [==============================] - 3s 74ms/step - loss: 0.0925 - accuracy: 0.9717
# Epoch 9/10
# 38/38 [==============================] - 3s 75ms/step - loss: 0.0656 - accuracy: 0.9783
# Epoch 10/10
# 38/38 [==============================] - 3s 73ms/step - loss: 0.0530 - accuracy: 0.9867

# %%
happy_model.evaluate(X_test, Y_test)
# Out:
# 5/5 [==============================] - 0s 30ms/step - loss: 0.2253 - accuracy: 0.8800
# [0.22525548934936523, 0.8799999952316284]

# %%
X_train_orig, Y_train_orig, X_test_orig, Y_test_orig, classes = load_signs_dataset()

# %%
index = 9
plt.imshow(X_train_orig[index])
print("y = " + str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 4

# %%
X_train = X_train_orig/255.
X_test = X_test_orig/255.
Y_train = convert_to_one_hot(Y_train_orig, 6).T
Y_test = convert_to_one_hot(Y_test_orig, 6).T

print ("number of training examples = " + str(X_train.shape[0]))
print ("number of test examples = " + str(X_test.shape[0]))
print ("X_train shape: " + str(X_train.shape))
print ("Y_train shape: " + str(Y_train.shape))
print ("X_test shape: " + str(X_test.shape))
print ("Y_test shape: " + str(Y_test.shape))
# Out:
# number of training examples = 1080
# number of test examples = 120
# X_train shape: (1080, 64, 64, 3)
# Y_train shape: (1080, 6)
# X_test shape: (120, 64, 64, 3)
# Y_test shape: (120, 6)

# %%
def convolutional_model(input_shape):
    input_img = tf.keras.Input(shape=input_shape)
    Z1 = tfl.Conv2D(8, 4, activation='linear', padding='same', strides=1)(input_img)
    A1 = tfl.ReLU()(Z1)
    P1 = tfl.MaxPool2D(pool_size=(8,8), strides=(8,8), padding='same')(A1)
    Z2 = tfl.Conv2D(16, 2, strides=1, padding='same')(P1)
    A2 = tfl.ReLU()(Z2)
    P2 = tfl.MaxPool2D(pool_size=(4,4), strides=(4,4), padding='same')(A2)
    F  = tfl.Flatten()(P2)
    outputs = tfl.Dense(6, activation='softmax')(F)
    
    model = tf.keras.Model(inputs=input_img, outputs=outputs)
    return model

# %%
conv_model = convolutional_model((64, 64, 3))
conv_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])
conv_model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 64, 64, 3)]       0
#
#  conv2d_1 (Conv2D)           (None, 64, 64, 8)         392
#
#  re_lu_1 (ReLU)              (None, 64, 64, 8)         0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 8)          0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 8, 8, 16)          528
#
#  re_lu_2 (ReLU)              (None, 8, 8, 16)          0
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 16)         0
#  2D)
#
#  flatten_1 (Flatten)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 6)                 390
#
# =================================================================
# Total params: 1,310
# Trainable params: 1,310
# Non-trainable params: 0
# _________________________________________________________________

# %%
train_dataset = tf.data.Dataset.from_tensor_slices((X_train, Y_train)).batch(32)
test_dataset = tf.data.Dataset.from_tensor_slices((X_test, Y_test)).batch(32)
history = conv_model.fit(train_dataset, epochs=150, validation_data=test_dataset)
# Out:
# Epoch 1/150
# 34/34 [==============================] - 3s 43ms/step - loss: 1.8204 - accuracy: 0.1602 - val_loss: 1.7899 - val_accuracy: 0.1667
# Epoch 2/150
# 34/34 [==============================] - 1s 38ms/step - loss: 1.7885 - accuracy: 0.1778 - val_loss: 1.7839 - val_accuracy: 0.2167
# Epoch 3/150
# 34/34 [==============================] - 1s 40ms/step - loss: 1.7841 - accuracy: 0.2065 - val_loss: 1.7800 - val_accuracy: 0.2417
# Epoch 4/150
# 34/34 [==============================] - 1s 40ms/step - loss: 1.7784 - accuracy: 0.2370 - val_loss: 1.7706 - val_accuracy: 0.2917
# Epoch 5/150
# 34/34 [==============================] - 1s 42ms/step - loss: 1.7695 - accuracy: 0.2880 - val_loss: 1.7614 - val_accuracy: 0.3500
# Epoch 6/150
# 34/34 [==============================] - 1s 41ms/step - loss: 1.7582 - accuracy: 0.3333 - val_loss: 1.7468 - val_accuracy: 0.3667
# Epoch 7/150
# 34/34 [==============================] - 1s 41ms/step - loss: 1.7438 - accuracy: 0.3500 - val_loss: 1.7280 - val_accuracy: 0.3417
# Epoch 8/150
# 34/34 [==============================] - 1s 40ms/step - loss: 1.7233 - accuracy: 0.3630 - val_loss: 1.7045 - val_accuracy: 0.3333
# Epoch 9/150
# 34/34 [==============================] - 1s 40ms/step - loss: 1.6965 - accuracy: 0.3824 - val_loss: 1.6728 - val_accuracy: 0.3667
# Epoch 10/150
# 34/34 [==============================] - 1s 42ms/step - loss: 1.6637 - accuracy: 0.3991 - val_loss: 1.6387 - val_accuracy: 0.3583
# Epoch 11/150
# 34/34 [==============================] - 1s 41ms/step - loss: 1.6186 - accuracy: 0.4315 - val_loss: 1.5840 - val_accuracy: 0.4000
# Epoch 12/150
# 34/34 [==============================] - 1s 44ms/step - loss: 1.5666 - accuracy: 0.4509 - val_loss: 1.5285 - val_accuracy: 0.4500
# Epoch 13/150
150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.7056 - accuracy: 0.7648 - val_loss: 0.8015 - val_accuracy: 0.7250
# Epoch 38/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.6930 - accuracy: 0.7639 - val_loss: 0.7846 - val_accuracy: 0.7167
# Epoch 39/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.6789 - accuracy: 0.7731 - val_loss: 0.7691 - val_accuracy: 0.7167
# Epoch 40/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.6679 - accuracy: 0.7750 - val_loss: 0.7610 - val_accuracy: 0.7333
# Epoch 41/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.6557 - accuracy: 0.7787 - val_loss: 0.7469 - val_accuracy: 0.7333
# Epoch 42/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.6427 - accuracy: 0.7815 - val_loss: 0.7364 - val_accuracy: 0.7333
# Epoch 43/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.6315 - accuracy: 0.7852 - val_loss: 0.7264 - val_accuracy: 0.7333
# Epoch 44/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.6205 - accuracy: 0.7917 - val_loss: 0.7163 - val_accuracy: 0.7333
# Epoch 45/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.6092 - accuracy: 0.7935 - val_loss: 0.7051 - val_accuracy: 0.7583
# Epoch 46/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.5990 - accuracy: 0.7963 - val_loss: 0.6958 - val_accuracy: 0.7583
# Epoch 47/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.5884 - accuracy: 0.8000 - val_loss: 0.6834 - val_accuracy: 0.7667
# Epoch 48/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.5787 - accuracy: 0.8028 - val_loss: 0.6743 - val_accuracy: 0.7667
# Epoch 49/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.5686 - accuracy: 0.8056 - val_loss: 0.6638 - val_accuracy: 0.7667
# Epoch 50/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.5601 - accuracy: 0.8130 - val_loss: 0.6560 - val_accuracy: 0.7667
# Epoch 51/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.5512 - accuracy: 0.8167 - val_loss: 0.6476 - val_accuracy: 0.7750
# Epoch 52/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.5427 - accuracy: 0.8204 - val_loss: 0.6408 - val_accuracy: 0.7750
# Epoch 53/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.5341 - accuracy: 0.8259 - val_loss: 0.6338 - val_accuracy: 0.7833
# Epoch 54/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.5269 - accuracy: 0.8269 - val_loss: 0.6259 - val_accuracy: 0.7833
# Epoch 55/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.5196 - accuracy: 0.8333 - val_loss: 0.6185 - val_accuracy: 0.7833
# Epoch 56/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.5135 - accuracy: 0.8333 - val_loss: 0.6125 - val_accuracy: 0.7833
# Epoch 57/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.5061 - accuracy: 0.8361 - val_loss: 0.6057 - val_accuracy: 0.7833
# Epoch 58/150
# 34/34 [==============================] - 2s 45ms/step - loss: 0.4995 - accuracy: 0.8361 - val_loss: 0.6000 - val_accuracy: 0.7833
# Epoch 59/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.4927 - accuracy: 0.8398 - val_loss: 0.5944 - val_accuracy: 0.7750
# Epoch 60/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.4861 - accuracy: 0.8454 - val_loss: 0.5873 - val_accuracy: 0.7750
# Epoch 61/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.4799 - accuracy: 0.8472 - val_loss: 0.5818 - val_accuracy: 0.7750
# Epoch 62/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.4739 - accuracy: 0.8491 - val_loss: 0.5752 - val_accuracy: 0.7750
# Epoch 63/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.4670 - accuracy: 0.8546 - val_loss: 0.5704 - val_accuracy: 0.7750
# Epoch 64/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0
150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.2321 - accuracy: 0.9324 - val_loss: 0.3416 - val_accuracy: 0.8583
# Epoch 132/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.2300 - accuracy: 0.9324 - val_loss: 0.3397 - val_accuracy: 0.8583
# Epoch 133/150
# 34/34 [==============================] - 2s 44ms/step - loss: 0.2275 - accuracy: 0.9352 - val_loss: 0.3377 - val_accuracy: 0.8667
# Epoch 134/150
# 34/34 [==============================] - 2s 44ms/step - loss: 0.2255 - accuracy: 0.9361 - val_loss: 0.3364 - val_accuracy: 0.8750
# Epoch 135/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.2231 - accuracy: 0.9370 - val_loss: 0.3343 - val_accuracy: 0.8750
# Epoch 136/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.2211 - accuracy: 0.9389 - val_loss: 0.3328 - val_accuracy: 0.8750
# Epoch 137/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.2186 - accuracy: 0.9417 - val_loss: 0.3306 - val_accuracy: 0.8750
# Epoch 138/150
# 34/34 [==============================] - 1s 43ms/step - loss: 0.2164 - accuracy: 0.9435 - val_loss: 0.3295 - val_accuracy: 0.8750
# Epoch 139/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.2146 - accuracy: 0.9444 - val_loss: 0.3274 - val_accuracy: 0.8833
# Epoch 140/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.2124 - accuracy: 0.9454 - val_loss: 0.3254 - val_accuracy: 0.8833
# Epoch 141/150
# 34/34 [==============================] - 1s 41ms/step - loss: 0.2105 - accuracy: 0.9454 - val_loss: 0.3242 - val_accuracy: 0.8833
# Epoch 142/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.2085 - accuracy: 0.9463 - val_loss: 0.3225 - val_accuracy: 0.8833
# Epoch 143/150
# 34/34 [==============================] - 2s 45ms/step - loss: 0.2064 - accuracy: 0.9463 - val_loss: 0.3203 - val_accuracy: 0.8917
# Epoch 144/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.2045 - accuracy: 0.9491 - val_loss: 0.3198 - val_accuracy: 0.8833
# Epoch 145/150
# 34/34 [==============================] - 1s 42ms/step - loss: 0.2024 - accuracy: 0.9472 - val_loss: 0.3186 - val_accuracy: 0.8833
# Epoch 146/150
# 34/34 [==============================] - 2s 45ms/step - loss: 0.2006 - accuracy: 0.9491 - val_loss: 0.3168 - val_accuracy: 0.8917
# Epoch 147/150
# 34/34 [==============================] - 2s 46ms/step - loss: 0.1986 - accuracy: 0.9500 - val_loss: 0.3162 - val_accuracy: 0.8917
# Epoch 148/150
# 34/34 [==============================] - 2s 46ms/step - loss: 0.1964 - accuracy: 0.9500 - val_loss: 0.3144 - val_accuracy: 0.8917
# Epoch 149/150
# 34/34 [==============================] - 2s 53ms/step - loss: 0.1946 - accuracy: 0.9528 - val_loss: 0.3137 - val_accuracy: 0.8833
# Epoch 150/150
# 34/34 [==============================] - 2s 48ms/step - loss: 0.1923 - accuracy: 0.9546 - val_loss: 0.3123 - val_accuracy: 0.8833

# %%
df_loss_acc = pd.DataFrame(history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_acc= df_loss_acc[['accuracy','val_accuracy']]
df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
df_acc.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='Accuracy')
# Out:
# C:\Users\turgu\AppData\Local\Temp\ipykernel_22660\974158325.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# C:\Users\turgu\AppData\Local\Temp\ipykernel_22660\974158325.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_acc.rename(columns={'accuracy':'train','val_accuracy':'validation'},inplace=True)
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Accuracy')]
